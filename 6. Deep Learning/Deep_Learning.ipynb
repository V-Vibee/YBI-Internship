# %% [markdown]
# **Computer Vision**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import skimage as ski
from skimage.io import imread,imshow
from skimage.color import rgb2gray, rgb2hsv
from skimage.transform import resize, rescale, rotate
from skimage.exposure import adjust_gamma
from skimage.filters import  sobel, sobel_h, sobel_v

# %%
ski.__version__
# Out:
# '0.19.3'

# %%
cat= imread('https://cdn.mos.cms.futurecdn.net/F3Bg3nsbsfJMWzkko9GThW-320-80.jpg')

# %%
cat
# Out:
# array([[[129, 183, 193],
#         [127, 181, 191],
#         [126, 180, 190],
#         ...,
#         [101, 179, 217],
#         [103, 181, 219],
#         [104, 182, 220]],
#
#        [[129, 183, 193],
#         [127, 181, 191],
#         [126, 180, 190],
#         ...,
#         [101, 179, 217],
#         [102, 180, 218],
#         [103, 181, 219]],
#
#        [[128, 182, 192],
#         [127, 181, 191],
#         [127, 181, 191],
#         ...,
#         [101, 179, 217],
#         [102, 180, 218],
#         [103, 181, 219]],
#
#        ...,
#
#        [[162, 170, 159],
#         [162, 170, 159],
#         [162, 170, 159],
#         ...,
#         [145, 128,  76],
#         [139, 123,  71],
#         [135, 120,  65]],
#
#        [[161, 169, 158],
#         [161, 169, 158],
#         [162, 170, 159],
#         ...,
#         [144, 127,  75],
#         [135, 119,  67],
#         [130, 114,  62]],
#
#        [[161, 169, 158],
#         [161, 169, 158],
#         [161, 169, 158],
#         ...,
#         [145, 127,  77],
#         [135, 119,  67],
#         [126, 110,  58]]], dtype=uint8)

# %%
type(cat)
# Out:
# numpy.ndarray

# %%
imshow(cat)

# %%
type(cat), cat.shape, cat.size, cat.min(), cat.max(), cat.mean()
# Out:
# (numpy.ndarray, (310, 320, 3), 297600, 0, 255, 132.07237903225806)

# %%
camera= ski.data.camera()

# %%
imshow(camera)

# %%
cat.shape
# Out:
# (310, 320, 3)

# %%
cat[:, :, ::-1]
# Out:
# array([[[193, 183, 129],
#         [191, 181, 127],
#         [190, 180, 126],
#         ...,
#         [217, 179, 101],
#         [219, 181, 103],
#         [220, 182, 104]],
#
#        [[193, 183, 129],
#         [191, 181, 127],
#         [190, 180, 126],
#         ...,
#         [217, 179, 101],
#         [218, 180, 102],
#         [219, 181, 103]],
#
#        [[192, 182, 128],
#         [191, 181, 127],
#         [191, 181, 127],
#         ...,
#         [217, 179, 101],
#         [218, 180, 102],
#         [219, 181, 103]],
#
#        ...,
#
#        [[159, 170, 162],
#         [159, 170, 162],
#         [159, 170, 162],
#         ...,
#         [ 76, 128, 145],
#         [ 71, 123, 139],
#         [ 65, 120, 135]],
#
#        [[158, 169, 161],
#         [158, 169, 161],
#         [159, 170, 162],
#         ...,
#         [ 75, 127, 144],
#         [ 67, 119, 135],
#         [ 62, 114, 130]],
#
#        [[158, 169, 161],
#         [158, 169, 161],
#         [158, 169, 161],
#         ...,
#         [ 77, 127, 145],
#         [ 67, 119, 135],
#         [ 58, 110, 126]]], dtype=uint8)

# %%
cat_gray=imshow(rgb2gray(cat))

# %%
imshow(resize(cat,(50,50)))
