# %% [markdown]
# **Import Dependencies**

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Bank%20Churn%20Modelling.csv")

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  Num Of Products  Has Credit Card  Is Active Member  \
# 0       0.00                1                1                 1
# 1   83807.86                1                0                 1
# 2  159660.80                3                1                 0
# 3       0.00                2                0                 0
# 4  125510.82                1                1                 1
#
#    Estimated Salary  Churn
# 0         101348.88      1
# 1         112542.58      0
# 2         113931.57      1
# 3          93826.63      0
# 4          79084.10      0

# %% [markdown]
# **Define Target & Features**

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'Num Of Products', 'Has Credit Card',
#        'Is Active Member', 'Estimated Salary', 'Churn'],
#       dtype='object')

# %%
y= df['Churn']
X= df[['CreditScore', 'Geography', 'Gender', 'Age',
       'Tenure', 'Balance', 'Num Of Products', 'Has Credit Card',
       'Is Active Member', 'Estimated Salary']]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  Num Of Products  \
# 0             619    France  Female   42       2       0.00                1
# 1             608     Spain  Female   41       1   83807.86                1
# 2             502    France  Female   42       8  159660.80                3
# 3             699    France  Female   39       1       0.00                2
# 4             850     Spain  Female   43       2  125510.82                1
# ...           ...       ...     ...  ...     ...        ...              ...
# 9995          771    France    Male   39       5       0.00                2
# 9996          516    France    Male   35      10   57369.61                1
# 9997          709    France  Female   36       7       0.00                1
# 9998          772   Germany    Male   42       3   75075.31                2
# 9999          792    France  Female   28       4  130142.79                1
#
#       Has Credit Card  Is Active Member  Estimated Salary
# 0                   1                 1         101348.88
# 1                   0                 1         112542.58
# 2                   1                 0         113931.57
# 3                   0                 0          93826.63
# 4                   1                 1          79084.10
# ...               ...               ...               ...
# 9995                1                 0          96270.64
# 9996                1                 1         101699.77
# 9997                0                 1          42085.58
# 9998                1                 0          92888.52
# 9999                1                 0          38190.78
#
# [10000 rows x 10 columns]

# %% [markdown]
# **Handling Nominal data**

# %%
X= pd.get_dummies(X)

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, random_state= 2529)

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import StandardScaler
ss= StandardScaler()
x_train= ss.fit_transform(X_train)
X_test= ss.transform(X_test)

# %% [markdown]
# **ANN**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#Input layer

model= Sequential()
model.add(Dense(12, activation='relu'))

# %%
# Hidden layer
model.add(Dense(12, activation='relu'))

# %%
# Output layer
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile

model.compile(optimizer='adam', loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
# Train

model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6421 - loss: 615.1854
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6726 - loss: 43.8465
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6587 - loss: 47.0395
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6798 - loss: 38.7911
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6719 - loss: 32.8502
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6914 - loss: 36.0237
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6759 - loss: 33.1505
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6811 - loss: 42.2495
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6733 - loss: 38.7892
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6671 - loss: 33.0719

# %%
# Prediction

y_pred= model.predict(X_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# since to check in binary form

y_pred= np.round(y_pred)
y_pred
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        ...,
#        [0.],
#        [1.],
#        [0.]], dtype=float32)

# %%
# Evaluate

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      2012
#            1       0.27      0.24      0.25       488
#
#     accuracy                           0.72      2500
#    macro avg       0.54      0.54      0.54      2500
# weighted avg       0.71      0.72      0.72      2500
