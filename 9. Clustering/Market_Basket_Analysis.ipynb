# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('https://github.com/YBIFoundation/MarketBasketAnalysis/raw/main/DataSet/BookstoreTransaction.csv')

# %%
df.head()
# Out:
#           Transaction
# 0    History,Bookmark
# 1    History,Bookmark
# 2    Fiction,Bookmark
# 3  Biography,Bookmark
# 4    History,Bookmark

# %%
Transaction =df['Transaction'].apply(lambda a: a.split(','))

# %%
transaction_list= list(Transaction)

# %%
transaction_list[0]
# Out:
# ['History', 'Bookmark']

# %%
transaction_list.count(['History', 'Bookmark'])
# Out:
# 25

# %%
from mlxtend.preprocessing import TransactionEncoder
encoder= TransactionEncoder().fit(Transaction)
onehot= encoder.transform(Transaction)

# %%
onehot =pd.DataFrame(onehot, columns= encoder.columns_)

# %%
onehot.mean()
# Out:
# Biography    0.404040
# Bookmark     1.000000
# Fiction      0.252525
# History      0.252525
# Poetry       0.090909
# dtype: float64

# %% [markdown]
# **Apriori, to find out the Rules**

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
frequent_itemset= apriori(onehot, min_support=0.03, max_len= 2, use_colnames=True)

# %% [markdown]
# **Association Rules**

# %%
association_rules(frequent_itemset, metric= 'lift', min_threshold= .01)
# Out:
#    antecedents  consequents  antecedent support  consequent support   support  \
# 0   (Bookmark)  (Biography)            1.000000            0.404040  0.404040
# 1  (Biography)   (Bookmark)            0.404040            1.000000  0.404040
# 2    (Fiction)   (Bookmark)            0.252525            1.000000  0.252525
# 3   (Bookmark)    (Fiction)            1.000000            0.252525  0.252525
# 4    (History)   (Bookmark)            0.252525            1.000000  0.252525
# 5   (Bookmark)    (History)            1.000000            0.252525  0.252525
# 6     (Poetry)   (Bookmark)            0.090909            1.000000  0.090909
# 7   (Bookmark)     (Poetry)            1.000000            0.090909  0.090909
#
#    confidence  lift  leverage  conviction  zhangs_metric
# 0    0.404040   1.0       0.0         1.0            0.0
# 1    1.000000   1.0       0.0         inf            0.0
# 2    1.000000   1.0       0.0         inf            0.0
# 3    0.252525   1.0       0.0         1.0            0.0
# 4    1.000000   1.0       0.0         inf            0.0
# 5    0.252525   1.0       0.0         1.0            0.0
# 6    1.000000   1.0       0.0         inf            0.0
# 7    0.090909   1.0       0.0         1.0            0.0
