# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
df.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  sibsp  parch  ticket
# 0     female      0      0   24160
# 1       male      1      2  113781
# 2     female      1      2  113781
# 3       male      1      2  113781
# 4     female      1      2  113781
# ...      ...    ...    ...     ...
# 1304  female      1      0    2665
# 1305  female      1      0    2665
# 1306    male      0      0    2656
# 1307    male      0      0    2670
# 1308    male      0      0  315082
#
# [1309 rows x 7 columns]

# %%
df.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df.dropna(how='all')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
df.dropna(thresh=13)
# Out:
#      pclass  survived                                          name     sex  \
# 0         1         1                 Allen, Miss. Elisabeth Walton  female
# 1         1         1                Allison, Master. Hudson Trevor    male
# 3         1         0          Allison, Mr. Hudson Joshua Creighton    male
# 5         1         1                           Anderson, Mr. Harry    male
# 6         1         1             Andrews, Miss. Kornelia Theodosia  female
# ..      ...       ...                                           ...     ...
# 520       2         1  Nourney, Mr. Alfred ("Baron von Drachstedt")    male
# 521       2         1                  Nye, Mrs. (Elizabeth Ramell)  female
# 573       2         1           Troutt, Miss. Edwina Celia "Winnie"  female
# 584       2         1                           Webber, Miss. Susan  female
# 605       3         1                 Abelseth, Mr. Olaus Jorgensen    male
#
#        age  sibsp  parch         ticket      fare    cabin embarked boat  \
# 0    29.00      0      0          24160  211.3375       B5        S    2
# 1     0.92      1      2         113781  151.5500  C22 C26        S   11
# 3    30.00      1      2         113781  151.5500  C22 C26        S  NaN
# 5    48.00      0      0          19952   26.5500      E12        S    3
# 6    63.00      1      0          13502   77.9583       D7        S   10
# ..     ...    ...    ...            ...       ...      ...      ...  ...
# 520  20.00      0      0  SC/PARIS 2166   13.8625      D38        C    7
# 521  29.00      0      0     C.A. 29395   10.5000      F33        S   11
# 573  27.00      0      0          34218   10.5000     E101        S   16
# 584  32.50      0      0          27267   13.0000     E101        S   12
# 605  25.00      0      0         348122    7.6500    F G63        S    A
#
#       body                        home.dest
# 0      NaN                     St Louis, MO
# 1      NaN  Montreal, PQ / Chesterville, ON
# 3    135.0  Montreal, PQ / Chesterville, ON
# 5      NaN                     New York, NY
# 6      NaN                       Hudson, NY
# ..     ...                              ...
# 520    NaN                 Cologne, Germany
# 521    NaN   Folkstone, Kent / New York, NY
# 573    NaN    Bath, England / Massachusetts
# 584    NaN           England / Hartford, CT
# 605    NaN               Perkins County, SD
#
# [186 rows x 14 columns]

# %%
# drop rows with missing values [list of columns to include]

df.dropna(subset=['boat'])
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1260       3         1                          Turja, Miss. Anna Sofia
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1299       3         0                              Yasbeck, Mr. Antoni
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S      2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S     11
# 5       male  48.00      0      0   19952   26.5500      E12        S      3
# 6     female  63.00      1      0   13502   77.9583       D7        S     10
# 8     female  53.00      2      0   11769   51.4792     C101        S      D
# ...      ...    ...    ...    ...     ...       ...      ...      ...    ...
# 1260  female  18.00      0      0    4138    9.8417      NaN        S     15
# 1261  female  63.00      0      0    4134    9.5875      NaN        S     15
# 1277    male  22.00      0      0    2658    7.2250      NaN        C  13 15
# 1286  female  38.00      0      0    2688    7.2292      NaN        C      C
# 1299    male  27.00      1      0    2659   14.4542      NaN        C      C
#
#       body                        home.dest
# 0      NaN                     St Louis, MO
# 1      NaN  Montreal, PQ / Chesterville, ON
# 5      NaN                     New York, NY
# 6      NaN                       Hudson, NY
# 8      NaN              Bayside, Queens, NY
# ...    ...                              ...
# 1260   NaN                              NaN
# 1261   NaN                              NaN
# 1277   NaN                              NaN
# 1286   NaN                              NaN
# 1299   NaN                              NaN
#
# [486 rows x 14 columns]

# %%
df['age'].fillna(29)
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305    29.00
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
df['age'].ffill()
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305    14.50
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
df['age'].bfill()
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305    26.50
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
df['age'].interpolate()
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305    20.50
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64
